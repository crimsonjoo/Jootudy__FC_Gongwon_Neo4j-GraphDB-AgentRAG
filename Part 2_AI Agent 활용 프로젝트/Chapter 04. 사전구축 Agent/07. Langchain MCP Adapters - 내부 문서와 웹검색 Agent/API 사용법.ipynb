# %% [markdown]
# ## 웹 검색을 위한 Tavily Search API

# %% [markdown]
# 🗝️ Tavily search API : https://app.tavily.com/home
#
# 🗒️ Tavily Search /search API Reference : https://docs.tavily.com/documentation/api-reference/endpoint/search

# %%
from dotenv import load_dotenv
import os

import requests
import json

load_dotenv()
tavily_api_key = os.getenv("TAVILY_API_KEY")

# %%
url = "https://api.tavily.com/search"

# %%
query = "스타벅스의 디카페인 메뉴들을 알려주세요."

# %%
payload = {
    "query": query,
    "topic": "general",
    "search_depth": "basic",
    "chunks_per_source": 3,
    "max_results": 3,
    "time_range": None,
    "days": 7,
    "include_answer": True,
    "include_raw_content": False,
    "include_images": False,
    "include_image_descriptions": False,
    "include_domains": [],
    "exclude_domains": [],
}
headers = {
    "Authorization": f"Bearer {tavily_api_key}",
    "Content-Type": "application/json",
}

response = requests.request("POST", url, json=payload, headers=headers)
print(response.text)
# Out:
# {"query":"스타벅스의 디카페인 메뉴들을 알려주세요.","follow_up_questions":null,"answer":"스타벅스의 디카페인 메뉴에는 디카페인 아메리카노, 디카페인 모카, 디카페인 라테 등이 있습니다. 카페인이 없어 임산부나 어린이에게 적합합니다. 메뉴는 시즌별로 변경될 수 있습니다.","images":[],"results":[{"title":"스타벅스 메뉴 가격 디카페인 메뉴판 리뷰 : 네이버 블로그","url":"https://blog.naver.com/minnyl/223436292922","content":"스타벅스 디카페인 메뉴 카페인이 없어서 임산부나 어린이, 그리고 카페인에 민감한 분들에게 적합한 음료들로 구성되어 있어요. 게다가 5월 3일 금요일부터 8일 수요일까지 오후 2시부터 매장 마감 전까지 방문하면 1+1 할인 혜택을 받을 수 있어요.","score":0.74229145,"raw_content":null},{"title":"스타벅스 퇴사자가 알려주는 디카페인 메뉴 추천 꿀 팁 : 네이버 블로그","url":"https://m.blog.naver.com/copsr325/223140608653","content":"스타벅스 퇴사자가 알려주는 디카페인 메뉴 추천 꿀 팁 ... 안녕하세요! 올리자 마자 반응이 좋은. 스타벅스 메뉴 추천! 오늘은 제목에서 보실수 있는 커피가 들어가지 않은. 메뉴들을 추천해 드리려 합니다!","score":0.6659544,"raw_content":null},{"title":"[스벅 꿀팁] 스타벅스 디카페인 음료 총정리","url":"https://mmij000.tistory.com/entry/스벅-꿀팁-스타벅스-디카페인-음료-총정리","content":"스타벅스에는 커피 말고도 다양한 종류의 음료들이 있다. 특히, 임산부나 아이들은 거의 카페인이 없는 음료를 찾을 것이다. 그래서 이번 포스팅에는 카페인이 아예 없는 스타벅스의 디카페인 음료와 사람들이 잘 모르는 고카페인 음료에 대해서 정리해 보았다. - 목 차 - 1. 스타벅스 디카페인 음료","score":0.64986813,"raw_content":null}],"response_time":2.03}

# %% [markdown]
# ## 날씨 검색을 위한 OpenWeatherMap API

# %% [markdown]
# 🗝️ OpenWeatherMap API : https://openweathermap.org/api (우측 상단 > My API Keys)
#
# - Free limit per day: 1,000 calls

# %%
load_dotenv()
open_weather_api_key = os.getenv("OPEN_WEATHRER_API_KEY")

# %% [markdown]
# [실시간 날씨 검색](https://openweathermap.org/current)

# %% [markdown]
# - 도시 이름 기반

# %%
city = "seoul"

# %%
api = f"""https://api.openweathermap.org/data/2.5/weather?q={city}&appid={open_weather_api_key}"""

result = requests.get(api)
data = json.loads(result.text)

print(data)
# Out:
# {'coord': {'lon': 126.9778, 'lat': 37.5683}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 297.91, 'feels_like': 297.09, 'temp_min': 297.91, 'temp_max': 298.93, 'pressure': 1013, 'humidity': 25, 'sea_level': 1013, 'grnd_level': 1003}, 'visibility': 10000, 'wind': {'speed': 4.63, 'deg': 190}, 'clouds': {'all': 0}, 'dt': 1745992582, 'sys': {'type': 1, 'id': 8105, 'country': 'KR', 'sunrise': 1745959090, 'sunset': 1746008418}, 'timezone': 32400, 'id': 1835848, 'name': 'Seoul', 'cod': 200}

# %% [markdown]
# - 위도 경도 기반

# %%
lon = 126 # 경도
lat = 37.5 # 위도
api = f"""https://api.openweathermap.org/data/3.0/onecall?lat={lat}&lon={lon}&lang=kr&appid={open_weather_api_key}"""

result = requests.get(api)
data = json.loads(result.text)

print(data)
# Out:
# {'lat': 37.5, 'lon': 126, 'timezone': 'Asia/Seoul', 'timezone_offset': 32400, 'current': {'dt': 1745992827, 'sunrise': 1745959332, 'sunset': 1746008646, 'temp': 285.19, 'feels_like': 284.43, 'pressure': 1012, 'humidity': 76, 'dew_point': 281.09, 'uvi': 4.24, 'clouds': 100, 'visibility': 10000, 'wind_speed': 10.45, 'wind_deg': 182, 'wind_gust': 18.24, 'weather': [{'id': 804, 'main': 'Clouds', 'description': '온흐림', 'icon': '04d'}]}, 'minutely': [{'dt': 1745992860, 'precipitation': 0}, {'dt': 1745992920, 'precipitation': 0}, {'dt': 1745992980, 'precipitation': 0}, {'dt': 1745993040, 'precipitation': 0}, {'dt': 1745993100, 'precipitation': 0}, {'dt': 1745993160, 'precipitation': 0}, {'dt': 1745993220, 'precipitation': 0}, {'dt': 1745993280, 'precipitation': 0}, {'dt': 1745993340, 'precipitation': 0}, {'dt': 1745993400, 'precipitation': 0}, {'dt': 1745993460, 'precipitation': 0}, {'dt': 1745993520, 'precipitation': 0}, {'dt': 1745993580, 'precipitation': 0}, {'dt': 1745993640, 'precipitation': 0}, {'dt': 1745993700, 'precipitation': 0}, {'dt': 1745993760, 'precipitation': 0}, {'dt': 1745993820, 'precipitation': 0}, {'dt': 1745993880, 'precipitation': 0}, {'dt': 1745993940, 'precipitation': 0}, {'dt': 1745994000, 'precipitation': 0}, {'dt': 1745994060, 'precipitation': 0}, {'dt': 1745994120, 'precipitation': 0}, {'dt': 1745994180, 'precipitation': 0}, {'dt': 1745994240, 'precipitation': 0}, {'dt': 1745994300, 'precipitation': 0}, {'dt': 1745994360, 'precipitation': 0}, {'dt': 1745994420, 'precipitation': 0}, {'dt': 1745994480, 'precipitation': 0}, {'dt': 1745994540, 'precipitation': 0}, {'dt': 1745994600, 'precipitation': 0}, {'dt': 1745994660, 'precipitation': 0}, {'dt': 1745994720, 'precipitation': 0}, {'dt': 1745994780, 'precipitation': 0}, {'dt': 1745994840, 'precipitation': 0}, {'dt': 1745994900, 'precipitation': 0}, {'dt': 1745994960, 'precipitation': 0}, {'dt': 1745995020, 'precipitation': 0}, {'dt': 1745995080, 'precipitation': 0}, {'dt': 1745995140, 'precipitation': 0}, {'dt': 1745995200, 'precipitation': 0}, {'dt': 1745995260, 'precipitation': 0}, {'dt': 1745995320, 'precipitation': 0}, {'dt': 1745995380, 'precipitation': 0}, {'dt': 1745995440, 'precipitation': 0}, {'dt': 1745995500, 'precipitation': 0}, {'dt': 1745995560, 'precipitation': 0}, {'dt': 1745995620, 'precipitation': 0}, {'dt': 1745995680, 'precipitation': 0}, {'dt': 1745995740, 'precipitation': 0}, {'dt': 1745995800, 'precipitation': 0}, {'dt': 1745995860, 'precipitation': 0}, {'dt': 1745995920, 'precipitation': 0}, {'dt': 1745995980, 'precipitation': 0}, {'dt': 1745996040, 'precipitation': 0}, {'dt': 1745996100, 'precipitation': 0}, {'dt': 1745996160, 'precipitation': 0}, {'dt': 1745996220, 'precipitation': 0}, {'dt': 1745996280, 'precipitation': 0}, {'dt': 1745996340, 'precipitation': 0}, {'dt': 1745996400, 'precipitation': 0}], 'hourly': [{'dt': 1745992800, 'temp': 285.19, 'feels_like': 284.43, 'pressure': 1012, 'humidity': 76, 'dew_point': 281.09, 'uvi': 4.24, 'clouds': 100, 'visibility': 10000, 'wind_speed': 10.45, 'wind_deg': 182, 'wind_gust': 18.24, 'weather': [{'id': 804, 'main': 'Clouds', 'description': '온흐림', 'icon': '04d'}], 'pop': 0}, {'dt': 1745996400, 'temp': 285.21, 'feels_like': 284.43, 'pressure': 1012, 'humidity': 75, 'dew_point': 280.92, 'uvi': 2.63, 'clouds': 91, 'visibility': 10000, 'wind_speed': 9.96, 'wind_deg': 182, 'wind_gust': 18.08, 'weather': [{'id': 804, 'main': 'Clouds', 'description': '온흐림', 'icon': '04d'}], 'pop': 0}, {'dt': 1746000000, 'temp': 285.28, 'feels_like': 284.51, 'pressure': 1012, 'humidity': 75, 'dew_point': 280.99, 'uvi': 1.22, 'clouds': 91, 'visibility': 10000, 'wind_speed': 9.28, 'wind_deg': 181, 'wind_gust': 17.12, 'weather': [{'id': 804, 'main': 'Clouds', 'description': '온흐림', 'icon': '04d'}], 'pop': 0}, {'dt': 1746003600, 'temp': 285.31, 'feels_like': 284.51, 'pressure': 1012, 'humidity': 74, 'dew_point': 280.82, 'uvi': 0.4, 'clouds': 90, 'visibility': 10000, 'wind_speed': 8.81, 'wind_deg': 178, 'wind_gust': 16 ...

# %%
data.keys()
# Out:
# dict_keys(['lat', 'lon', 'timezone', 'timezone_offset', 'current', 'minutely', 'hourly', 'daily'])

# %%
data['daily']
# Out:
# [{'dt': 1745982000,
#   'sunrise': 1745959332,
#   'sunset': 1746008646,
#   'moonrise': 1745964120,
#   'moonset': 1746020940,
#   'moon_phase': 0.09,
#   'summary': 'There will be clear sky until morning, then partly cloudy',
#   'temp': {'day': 285,
#    'min': 284.31,
#    'max': 286.2,
#    'night': 286.2,
#    'eve': 285.31,
#    'morn': 284.46},
#   'feels_like': {'day': 284.28,
#    'night': 285.31,
#    'eve': 284.51,
#    'morn': 283.71},
#   'pressure': 1013,
#   'humidity': 78,
#   'dew_point': 281.29,
#   'wind_speed': 11.3,
#   'wind_deg': 181,
#   'wind_gust': 21.68,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': '온흐림',
#     'icon': '04d'}],
#   'clouds': 99,
#   'pop': 0,
#   'uvi': 6.44},
#  {'dt': 1746068400,
#   'sunrise': 1746045663,
#   'sunset': 1746095101,
#   'moonrise': 1746053940,
#   'moonset': 1746111300,
#   'moon_phase': 0.13,
#   'summary': 'Expect a day of partly cloudy with rain',
#   'temp': {'day': 284.46,
#    'min': 283.59,
#    'max': 286.23,
#    'night': 283.9,
#    'eve': 283.84,
#    'morn': 286.05},
#   'feels_like': {'day': 284.15,
#    'night': 283.12,
#    'eve': 283.11,
#    'morn': 285.38},
#   'pressure': 1004,
#   'humidity': 96,
#   'dew_point': 283.92,
#   'wind_speed': 17.23,
#   'wind_deg': 184,
#   'wind_gust': 27.03,
#   'weather': [{'id': 502,
#     'main': 'Rain',
#     'description': '강한 비',
#     'icon': '10d'}],
#   'clouds': 100,
#   'pop': 1,
#   'rain': 16.14,
#   'uvi': 2.08},
#  {'dt': 1746154800,
#   'sunrise': 1746131995,
#   'sunset': 1746181556,
#   'moonrise': 1746144240,
#   'moonset': 0,
#   'moon_phase': 0.17,
#   'summary': 'Expect a day of partly cloudy with rain',
#   'temp': {'day': 284.28,
#    'min': 283.62,
#    'max': 285.14,
#    'night': 283.62,
#    'eve': 284.83,
#    'morn': 283.97},
#   'feels_like': {'day': 283.46,
#    'night': 282.76,
#    'eve': 284.01,
#    'morn': 283.09},
#   'pressure': 1011,
#   'humidity': 77,
#   'dew_point': 280.51,
#   'wind_speed': 12.37,
#   'wind_deg': 280,
#   'wind_gust': 16.9,
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': '실 비',
#     'icon': '10d'}],
#   'clouds': 100,
#   'pop': 0.56,
#   'rain': 0.21,
#   'uvi': 6.76},
#  {'dt': 1746241200,
#   'sunrise': 1746218328,
#   'sunset': 1746268012,
#   'moonrise': 1746234780,
#   'moonset': 1746200880,
#   'moon_phase': 0.2,
#   'summary': 'Expect a day of partly cloudy with rain',
#   'temp': {'day': 283.35,
#    'min': 282.67,
#    'max': 284.19,
#    'night': 283.93,
#    'eve': 284.19,
#    'morn': 283.25},
#   'feels_like': {'day': 282.75,
#    'night': 283.36,
#    'eve': 283.65,
#    'morn': 282.72},
#   'pressure': 1007,
#   'humidity': 89,
#   'dew_point': 281.57,
#   'wind_speed': 8.58,
#   'wind_deg': 277,
#   'wind_gust': 12.44,
#   'weather': [{'id': 502,
#     'main': 'Rain',
#     'description': '강한 비',
#     'icon': '10d'}],
#   'clouds': 97,
#   'pop': 1,
#   'rain': 17.37,
#   'uvi': 6.96},
#  {'dt': 1746327600,
#   'sunrise': 1746304663,
#   'sunset': 1746354467,
#   'moonrise': 1746325380,
#   'moonset': 1746289860,
#   'moon_phase': 0.25,
#   'summary': 'There will be clear sky today',
#   'temp': {'day': 283.95,
#    'min': 283.95,
#    'max': 284.65,
#    'night': 284.65,
#    'eve': 284.26,
#    'morn': 284.11},
#   'feels_like': {'day': 283.17,
#    'night': 283.76,
#    'eve': 283.36,
#    'morn': 283.32},
#   'pressure': 1010,
#   'humidity': 80,
#   'dew_point': 280.75,
#   'wind_speed': 13.21,
#   'wind_deg': 294,
#   'wind_gust': 18.61,
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': '맑음',
#     'icon': '01d'}],
#   'clouds': 0,
#   'pop': 0,
#   'uvi': 6.88},
#  {'dt': 1746414000,
#   'sunrise': 1746390999,
#   'sunset': 1746440922,
#   'moonrise': 1746415740,
#   'moonset': 1746378240,
#   'moon_phase': 0.27,
#   'summary': 'You can expect partly cloudy in the morning, with clearing in the afternoon',
#   'temp': {'day': 285.23,
#    'min': 284.58,
#    'max': 285.23,
#    'night': 284.97,
#    'eve': 285.15,
#    'morn': 284.78},
#   'feels_like': {'day': 284.48,
#    'night': 284.32,
#    'eve': 284.49,
#    'morn': 283.83},
#   'pressure': 1015,
#   'humidity': 76,
#   'dew_point': 281.09,
#   'wind_speed': 7.87,
#   'wind_deg': 269,
#   'wind_gust': 12.86,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': '온흐림',
#     'icon': '04d'}],
#   'clouds': 100,
#   'pop': 0,
#   'uvi': 7},
#  {'dt': 1746500400,
#   'sunrise': 1746477336,
#   'sunset': 1746527377,
#   'moonrise': 1746505920,
#   'moonset': 1746466320,
#   'moon_phase': 0.3,
#   'summary': 'You can expect partly cloudy in the morning, with rain in the afternoon',
#   'temp': {'day': 285.01,
#    'min': 284.51,
#    'max': 285.34,
#    'night': 284.51,
#    'eve': 284.72,
#    'morn': 285.03},
#   'feels_like': {'day': 284.18,
#    'night': 283.66,
#    'eve': 283.81,
#    'morn': 284.18},
#   'pressure': 1013,
#   'humidity': 74,
#   'dew_point': 280.57,
#   'wind_speed': 5.58,
#   'wind_deg': 171,
#   'wind_gust': 6.53,
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': '실 비',
#     'icon': '10d'}],
#   'clouds': 100,
#   'pop': 0.2,
#   'rain': 0.18,
#   'uvi': 7},
#  {'dt': 1746586800,
#   'sunrise': 1746563674,
#   'sunset': 1746613832,
#   'moonrise': 1746595920,
#   'moonset': 1746554160,
#   'moon_phase': 0.33,
#   'summary': 'Expect a day of partly cloudy with clear spells',
#   'temp': {'day': 285.24,
#    'min': 284.43,
#    'max': 287.69,
#    'night': 286.95,
#    'eve': 287.69,
#    'morn': 284.43},
#   'feels_like': {'day': 284.44,
#    'night': 286.16,
#    'eve': 286.87,
#    'morn': 283.75},
#   'pressure': 1016,
#   'humidity': 74,
#   'dew_point': 280.81,
#   'wind_speed': 4.22,
#   'wind_deg': 49,
#   'wind_gust': 5.16,
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': '맑음',
#     'icon': '01d'}],
#   'clouds': 0,
#   'pop': 0,
#   'uvi': 7}]

# %%
data['hourly']
# Out:
# [{'dt': 1745992800,
#   'temp': 285.19,
#   'feels_like': 284.43,
#   'pressure': 1012,
#   'humidity': 76,
#   'dew_point': 281.09,
#   'uvi': 4.24,
#   'clouds': 100,
#   'visibility': 10000,
#   'wind_speed': 10.45,
#   'wind_deg': 182,
#   'wind_gust': 18.24,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': '온흐림',
#     'icon': '04d'}],
#   'pop': 0},
#  {'dt': 1745996400,
#   'temp': 285.21,
#   'feels_like': 284.43,
#   'pressure': 1012,
#   'humidity': 75,
#   'dew_point': 280.92,
#   'uvi': 2.63,
#   'clouds': 91,
#   'visibility': 10000,
#   'wind_speed': 9.96,
#   'wind_deg': 182,
#   'wind_gust': 18.08,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': '온흐림',
#     'icon': '04d'}],
#   'pop': 0},
#  {'dt': 1746000000,
#   'temp': 285.28,
#   'feels_like': 284.51,
#   'pressure': 1012,
#   'humidity': 75,
#   'dew_point': 280.99,
#   'uvi': 1.22,
#   'clouds': 91,
#   'visibility': 10000,
#   'wind_speed': 9.28,
#   'wind_deg': 181,
#   'wind_gust': 17.12,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': '온흐림',
#     'icon': '04d'}],
#   'pop': 0},
#  {'dt': 1746003600,
#   'temp': 285.31,
#   'feels_like': 284.51,
#   'pressure': 1012,
#   'humidity': 74,
#   'dew_point': 280.82,
#   'uvi': 0.4,
#   'clouds': 90,
#   'visibility': 10000,
#   'wind_speed': 8.81,
#   'wind_deg': 178,
#   'wind_gust': 16.99,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': '온흐림',
#     'icon': '04d'}],
#   'pop': 0},
#  {'dt': 1746007200,
#   'temp': 285.44,
#   'feels_like': 284.6,
#   'pressure': 1011,
#   'humidity': 72,
#   'dew_point': 280.54,
#   'uvi': 0,
#   'clouds': 84,
#   'visibility': 10000,
#   'wind_speed': 8.79,
#   'wind_deg': 178,
#   'wind_gust': 17.41,
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': '튼구름',
#     'icon': '04d'}],
#   'pop': 0},
#  {'dt': 1746010800,
#   'temp': 285.49,
#   'feels_like': 284.66,
#   'pressure': 1012,
#   'humidity': 72,
#   'dew_point': 280.64,
#   'uvi': 0,
#   'clouds': 72,
#   'visibility': 10000,
#   'wind_speed': 8.16,
#   'wind_deg': 177,
#   'wind_gust': 16.98,
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': '튼구름',
#     'icon': '04n'}],
#   'pop': 0},
#  {'dt': 1746014400,
#   'temp': 285.74,
#   'feels_like': 284.88,
#   'pressure': 1012,
#   'humidity': 70,
#   'dew_point': 280.28,
#   'uvi': 0,
#   'clouds': 70,
#   'visibility': 10000,
#   'wind_speed': 8.47,
#   'wind_deg': 178,
#   'wind_gust': 17.34,
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': '튼구름',
#     'icon': '04n'}],
#   'pop': 0},
#  {'dt': 1746018000,
#   'temp': 285.91,
#   'feels_like': 285.02,
#   'pressure': 1012,
#   'humidity': 68,
#   'dew_point': 280.27,
#   'uvi': 0,
#   'clouds': 17,
#   'visibility': 10000,
#   'wind_speed': 9.25,
#   'wind_deg': 178,
#   'wind_gust': 19.05,
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': '약간의 구름이 낀 하늘',
#     'icon': '02n'}],
#   'pop': 0},
#  {'dt': 1746021600,
#   'temp': 286.2,
#   'feels_like': 285.31,
#   'pressure': 1011,
#   'humidity': 67,
#   'dew_point': 280.29,
#   'uvi': 0,
#   'clouds': 15,
#   'visibility': 10000,
#   'wind_speed': 11.3,
#   'wind_deg': 181,
#   'wind_gust': 21.68,
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': '약간의 구름이 낀 하늘',
#     'icon': '02n'}],
#   'pop': 0},
#  {'dt': 1746025200,
#   'temp': 285.98,
#   'feels_like': 285.25,
#   'pressure': 1011,
#   'humidity': 74,
#   'dew_point': 281.45,
#   'uvi': 0,
#   'clouds': 15,
#   'visibility': 10000,
#   'wind_speed': 11.75,
#   'wind_deg': 171,
#   'wind_gust': 21.81,
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': '약간의 구름이 낀 하늘',
#     'icon': '02n'}],
#   'pop': 0},
#  {'dt': 1746028800,
#   'temp': 285.77,
#   'feels_like': 285.12,
#   'pressure': 1010,
#   'humidity': 78,
#   'dew_point': 282.07,
#   'uvi': 0,
#   'clouds': 12,
#   'visibility': 10000,
#   'wind_speed': 10.89,
#   'wind_deg': 167,
#   'wind_gust': 20.76,
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': '약간의 구름이 낀 하늘',
#     'icon': '02n'}],
#   'pop': 0},
#  {'dt': 1746032400,
#   'temp': 285.92,
#   'feels_like': 285.18,
#   'pressure': 1009,
#   'humidity': 74,
#   'dew_point': 281.58,
#   'uvi': 0,
#   'clouds': 10,
#   'visibility': 10000,
#   'wind_speed': 12.43,
#   'wind_deg': 169,
#   'wind_gust': 22.62,
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': '맑음',
#     'icon': '01n'}],
#   'pop': 0},
#  {'dt': 1746036000,
#   'temp': 286.15,
#   'feels_like': 285.36,
#   'pressure': 1009,
#   'humidity': 71,
#   'dew_point': 281.02,
#   'uvi': 0,
#   'clouds': 26,
#   'visibility': 10000,
#   'wind_speed': 12.86,
#   'wind_deg': 169,
#   'wind_gust': 22.54,
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': '구름조금',
#     'icon': '03n'}],
#   'pop': 0},
#  {'dt': 1746039600,
#   'temp': 286.21,
#   'feels_like': 285.45,
#   'pressure': 1009,
#   'humidity': 72,
#   'dew_point': 281.24,
#   'uvi': 0,
#   'clouds': 4,
#   'visibility': 10000,
#   'wind_speed': 13.26,
#   'wind_deg': 170,
#   'wind_gust': 23.11,
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': '맑음',
#     'icon': '01n'}],
#   'pop': 0},
#  {'dt': 1746043200,
#   'temp': 286.23,
#   'feels_like': 285.47,
#   'pressure': 1007,
#   'humidity': 72,
#   'dew_point': 281.41,
#   'uvi': 0,
#   'clouds': 52,
#   'visibility': 10000,
#   'wind_speed': 14.79,
#   'wind_deg': 170,
#   'wind_gust': 24.69,
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': '튼구름',
#     'icon': '04n'}],
#   'pop': 0},
#  {'dt': 1746046800,
#   'temp': 286.05,
#   'feels_like': 285.38,
#   'pressure': 1006,
#   'humidity': 76,
#   'dew_point': 281.94,
#   'uvi': 0,
#   'clouds': 68,
#   'visibility': 10000,
#   'wind_speed': 15.84,
#   'wind_deg': 171,
#   'wind_gust': 26.33,
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': '튼구름',
#     'icon': '04d'}],
#   'pop': 0.1},
#  {'dt': 1746050400,
#   'temp': 286.19,
#   'feels_like': 285.59,
#   'pressure': 1005,
#   'humidity': 78,
#   'dew_point': 282.41,
#   'uvi': 0.19,
#   'clouds': 76,
#   'visibility': 10000,
#   'wind_speed': 16.88,
#   'wind_deg': 168,
#   'wind_gust': 27.03,
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': '실 비',
#     'icon': '10d'}],
#   'pop': 0.73,
#   'rain': {'1h': 0.47}},
#  {'dt': 1746054000,
#   'temp': 285.87,
#   'feels_like': 285.29,
#   'pressure': 1005,
#   'humidity': 80,
#   'dew_point': 282.47,
#   'uvi': 0.27,
#   'clouds': 81,
#   'visibility': 4984,
#   'wind_speed': 16.91,
#   'wind_deg': 186,
#   'wind_gust': 26.42,
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': '보통 비',
#     'icon': '10d'}],
#   'pop': 0.98,
#   'rain': {'1h': 1.81}},
#  {'dt': 1746057600,
#   'temp': 284.68,
#   'feels_like': 284.34,
#   'pressure': 1005,
#   'humidity': 94,
#   'dew_point': 283.73,
#   'uvi': 0.26,
#   'clouds': 84,
#   'visibility': 5360,
#   'wind_speed': 17.23,
#   'wind_deg': 184,
#   'wind_gust': 24.53,
#   'weather': [{'id': 502,
#     'main': 'Rain',
#     'description': '강한 비',
#     'icon': '10d'}],
#   'pop': 1,
#   'rain': {'1h': 8.73}},
#  {'dt': 1746061200,
#   'temp': 284.83,
#   'feels_like': 284.51,
#   'pressure': 1005,
#   'humidity': 94,
#   'dew_point': 283.83,
#   'uvi': 0.71,
#   'clouds': 100,
#   'visibility': 8587,
#   'wind_speed': 15.93,
#   'wind_deg': 180,
#   'wind_gust': 22.24,
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': '보통 비',
#     'icon': '10d'}],
#   'pop': 1,
#   'rain': {'1h': 3.45}},
#  {'dt': 1746064800,
#   'temp': 284.68,
#   'feels_like': 284.37,
#   'pressure': 1005,
#   'humidity': 95,
#   'dew_point': 283.95,
#   'uvi': 0.39,
#   'clouds': 100,
#   'visibility': 10000,
#   'wind_speed': 14.74,
#   'wind_deg': 188,
#   'wind_gust': 22.72,
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': '보통 비',
#     'icon': '10d'}],
#   'pop': 1,
#   'rain': {'1h': 1.44}},
#  {'dt': 1746068400,
#   'temp': 284.46,
#   'feels_like': 284.15,
#   'pressure': 1004,
#   'humidity': 96,
#   'dew_point': 283.92,
#   'uvi': 0.48,
#   'clouds': 100,
#   'visibility': 10000,
#   'wind_speed': 12.94,
#   'wind_deg': 204,
#   'wind_gust': 17.98,
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': '실 비',
#     'icon': '10d'}],
#   'pop': 1,
#   'rain': {'1h': 0.24}},
#  {'dt': 1746072000,
#   'temp': 284.28,
#   'feels_like': 284.01,
#   'pressure': 1005,
#   'humidity': 98,
#   'dew_point': 283.95,
#   'uvi': 1.02,
#   'clouds': 100,
#   'visibility': 4369,
#   'wind_speed': 10.28,
#   'wind_deg': 218,
#   'wind_gust': 13.21,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': '온흐림',
#     'icon': '04d'}],
#   'pop': 0.8},
#  {'dt': 1746075600,
#   'temp': 284.13,
#   'feels_like': 283.76,
#   'pressure': 1004,
#   'humidity': 95,
#   'dew_point': 283.36,
#   'uvi': 2.08,
#   'clouds': 100,
#   'visibility': 10000,
#   'wind_speed': 8.58,
#   'wind_deg': 262,
#   'wind_gust': 11.53,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': '온흐림',
#     'icon': '04d'}],
#   'pop': 0.8},
#  {'dt': 1746079200,
#   'temp': 283.89,
#   'feels_like': 283.45,
#   'pressure': 1005,
#   'humidity': 93,
#   'dew_point': 282.84,
#   'uvi': 1.56,
#   'clouds': 100,
#   'visibility': 10000,
#   'wind_speed': 8.64,
#   'wind_deg': 276,
#   'wind_gust': 13.09,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': '온흐림',
#     'icon': '04d'}],
#   'pop': 0.8},
#  {'dt': 1746082800,
#   'temp': 284.1,
#   'feels_like': 283.57,
#   'pressure': 1005,
#   'humidity': 89,
#   'dew_point': 282.42,
#   'uvi': 1.45,
#   'clouds': 100,
#   'visibility': 10000,
#   'wind_speed': 8.05,
#   'wind_deg': 270,
#   'wind_gust': 11.96,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': '온흐림',
#     'icon': '04d'}],
#   'pop': 0},
#  {'dt': 1746086400,
#   'temp': 283.92,
#   'feels_like': 283.43,
#   'pressure': 1005,
#   'humidity': 91,
#   'dew_point': 282.43,
#   'uvi': 0.87,
#   'clouds': 100,
#   'visibility': 10000,
#   'wind_speed': 7.03,
#   'wind_deg': 250,
#   'wind_gust': 9.12,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': '온흐림',
#     'icon': '04d'}],
#   'pop': 0},
#  {'dt': 1746090000,
#   'temp': 283.84,
#   'feels_like': 283.11,
#   'pressure': 1005,
#   'humidity': 82,
#   'dew_point': 280.96,
#   'uvi': 0.39,
#   'clouds': 100,
#   'visibility': 10000,
#   'wind_speed': 9.24,
#   'wind_deg': 255,
#   'wind_gust': 13.02,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': '온흐림',
#     'icon': '04d'}],
#   'pop': 0},
#  {'dt': 1746093600,
#   'temp': 283.97,
#   'feels_like': 283.01,
#   'pressure': 1005,
#   'humidity': 73,
#   'dew_point': 279.34,
#   'uvi': 0,
#   'clouds': 79,
#   'visibility': 10000,
#   'wind_speed': 10.8,
#   'wind_deg': 268,
#   'wind_gust': 15.98,
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': '튼구름',
#     'icon': '04d'}],
#   'pop': 0},
#  {'dt': 1746097200,
#   'temp': 284.01,
#   'feels_like': 283.03,
#   'pressure': 1006,
#   'humidity': 72,
#   'dew_point': 279.06,
#   'uvi': 0,
#   'clouds': 63,
#   'visibility': 10000,
#   'wind_speed': 12.59,
#   'wind_deg': 271,
#   'wind_gust': 17.12,
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': '튼구름',
#     'icon': '04n'}],
#   'pop': 0},
#  {'dt': 1746100800,
#   'temp': 283.66,
#   'feels_like': 282.86,
#   'pressure': 1007,
#   'humidity': 80,
#   'dew_point': 280.46,
#   'uvi': 0,
#   'clouds': 52,
#   'visibility': 10000,
#   'wind_speed': 12.9,
#   'wind_deg': 275,
#   'wind_gust': 15.85,
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': '튼구름',
#     'icon': '04n'}],
#   'pop': 0},
#  {'dt': 1746104400,
#   'temp': 283.59,
#   'feels_like': 282.86,
#   'pressure': 1007,
#   'humidity': 83,
#   'dew_point': 280.79,
#   'uvi': 0,
#   'clouds': 14,
#   'visibility': 10000,
#   'wind_speed': 13.17,
#   'wind_deg': 278,
#   'wind_gust': 16.83,
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': '약간의 구름이 낀 하늘',
#     'icon': '02n'}],
#   'pop': 0},
#  {'dt': 1746108000,
#   'temp': 283.9,
#   'feels_like': 283.12,
#   'pressure': 1008,
#   'humidity': 80,
#   'dew_point': 280.65,
#   'uvi': 0,
#   'clouds': 56,
#   'visibility': 10000,
#   'wind_speed': 13.5,
#   'wind_deg': 287,
#   'wind_gust': 18.43,
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': '튼구름',
#     'icon': '04n'}],
#   'pop': 0},
#  {'dt': 1746111600,
#   'temp': 283.7,
#   'feels_like': 282.9,
#   'pressure': 1008,
#   'humidity': 80,
#   'dew_point': 280.4,
#   'uvi': 0,
#   'clouds': 46,
#   'visibility': 10000,
#   'wind_speed': 12.37,
#   'wind_deg': 280,
#   'wind_gust': 16.39,
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': '구름조금',
#     'icon': '03n'}],
#   'pop': 0},
#  {'dt': 1746115200,
#   'temp': 283.66,
#   'feels_like': 282.91,
#   'pressure': 1008,
#   'humidity': 82,
#   'dew_point': 280.67,
#   'uvi': 0,
#   'clouds': 35,
#   'visibility': 10000,
#   'wind_speed': 11.46,
#   'wind_deg': 274,
#   'wind_gust': 15.06,
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': '구름조금',
#     'icon': '03n'}],
#   'pop': 0},
#  {'dt': 1746118800,
#   'temp': 283.68,
#   'feels_like': 282.96,
#   'pressure': 1007,
#   'humidity': 83,
#   'dew_point': 280.96,
#   'uvi': 0,
#   'clouds': 28,
#   'visibility': 10000,
#   'wind_speed': 10.63,
#   'wind_deg': 277,
#   'wind_gust': 14.5,
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': '구름조금',
#     'icon': '03n'}],
#   'pop': 0},
#  {'dt': 1746122400,
#   'temp': 283.86,
#   'feels_like': 283.1,
#   'pressure': 1008,
#   'humidity': 81,
#   'dew_point': 280.78,
#   'uvi': 0,
#   'clouds': 24,
#   'visibility': 10000,
#   'wind_speed': 11.05,
#   'wind_deg': 276,
#   'wind_gust': 16.11,
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': '약간의 구름이 낀 하늘',
#     'icon': '02n'}],
#   'pop': 0},
#  {'dt': 1746126000,
#   'temp': 283.93,
#   'feels_like': 283.13,
#   'pressure': 1008,
#   'humidity': 79,
#   'dew_point': 280.42,
#   'uvi': 0,
#   'clouds': 0,
#   'visibility': 10000,
#   'wind_speed': 11.82,
#   'wind_deg': 282,
#   'wind_gust': 16.9,
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': '맑음',
#     'icon': '01n'}],
#   'pop': 0},
#  {'dt': 1746129600,
#   'temp': 284.14,
#   'feels_like': 283.25,
#   'pressure': 1008,
#   'humidity': 75,
#   'dew_point': 279.85,
#   'uvi': 0,
#   'clouds': 0,
#   'visibility': 10000,
#   'wind_speed': 10.25,
#   'wind_deg': 289,
#   'wind_gust': 16.18,
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': '맑음',
#     'icon': '01n'}],
#   'pop': 0},
#  {'dt': 1746133200,
#   'temp': 283.97,
#   'feels_like': 283.09,
#   'pressure': 1009,
#   'humidity': 76,
#   'dew_point': 279.88,
#   'uvi': 0,
#   'clouds': 2,
#   'visibility': 10000,
#   'wind_speed': 9.52,
#   'wind_deg': 290,
#   'wind_gust': 15.65,
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': '맑음',
#     'icon': '01d'}],
#   'pop': 0},
#  {'dt': 1746136800,
#   'temp': 283.94,
#   'feels_like': 283.06,
#   'pressure': 1009,
#   'humidity': 76,
#   'dew_point': 279.86,
#   'uvi': 0.33,
#   'clouds': 26,
#   'visibility': 10000,
#   'wind_speed': 9.26,
#   'wind_deg': 290,
#   'wind_gust': 14.75,
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': '구름조금',
#     'icon': '03d'}],
#   'pop': 0},
#  {'dt': 1746140400,
#   'temp': 284.04,
#   'feels_like': 283.17,
#   'pressure': 1010,
#   'humidity': 76,
#   'dew_point': 279.95,
#   'uvi': 1.06,
#   'clouds': 41,
#   'visibility': 10000,
#   'wind_speed': 8.93,
#   'wind_deg': 292,
#   'wind_gust': 14.29,
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': '구름조금',
#     'icon': '03d'}],
#   'pop': 0},
#  {'dt': 1746144000,
#   'temp': 284.09,
#   'feels_like': 283.22,
#   'pressure': 1010,
#   'humidity': 76,
#   'dew_point': 280.06,
#   'uvi': 2.37,
#   'clouds': 39,
#   'visibility': 10000,
#   'wind_speed': 7.86,
#   'wind_deg': 288,
#   'wind_gust': 12.12,
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': '구름조금',
#     'icon': '03d'}],
#   'pop': 0},
#  {'dt': 1746147600,
#   'temp': 284.15,
#   'feels_like': 283.32,
#   'pressure': 1010,
#   'humidity': 77,
#   'dew_point': 280.28,
#   'uvi': 3.96,
#   'clouds': 100,
#   'visibility': 10000,
#   'wind_speed': 7.14,
#   'wind_deg': 282,
#   'wind_gust': 10.65,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': '온흐림',
#     'icon': '04d'}],
#   'pop': 0},
#  {'dt': 1746151200,
#   'temp': 284.1,
#   'feels_like': 283.31,
#   'pressure': 1011,
#   'humidity': 79,
#   'dew_point': 280.56,
#   'uvi': 5.61,
#   'clouds': 100,
#   'visibility': 10000,
#   'wind_speed': 6.94,
#   'wind_deg': 273,
#   'wind_gust': 9.53,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': '온흐림',
#     'icon': '04d'}],
#   'pop': 0},
#  {'dt': 1746154800,
#   'temp': 284.28,
#   'feels_like': 283.46,
#   'pressure': 1011,
#   'humidity': 77,
#   'dew_point': 280.51,
#   'uvi': 6.59,
#   'clouds': 100,
#   'visibility': 10000,
#   'wind_speed': 7.11,
#   'wind_deg': 266,
#   'wind_gust': 9.99,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': '온흐림',
#     'icon': '04d'}],
#   'pop': 0},
#  {'dt': 1746158400,
#   'temp': 284.49,
#   'feels_like': 283.66,
#   'pressure': 1010,
#   'humidity': 76,
#   'dew_point': 280.42,
#   'uvi': 6.76,
#   'clouds': 98,
#   'visibility': 10000,
#   'wind_speed': 7.23,
#   'wind_deg': 259,
#   'wind_gust': 10.18,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': '온흐림',
#     'icon': '04d'}],
#   'pop': 0},
#  {'dt': 1746162000,
#   'temp': 284.5,
#   'feels_like': 283.68,
#   'pressure': 1010,
#   'humidity': 76,
#   'dew_point': 280.48,
#   'uvi': 5.64,
#   'clouds': 98,
#   'visibility': 10000,
#   'wind_speed': 7.33,
#   'wind_deg': 255,
#   'wind_gust': 9.81,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': '온흐림',
#     'icon': '04d'}],
#   'pop': 0}]

# %%
data['current']
# Out:
# {'dt': 1745992827,
#  'sunrise': 1745959332,
#  'sunset': 1746008646,
#  'temp': 285.19,
#  'feels_like': 284.43,
#  'pressure': 1012,
#  'humidity': 76,
#  'dew_point': 281.09,
#  'uvi': 4.24,
#  'clouds': 100,
#  'visibility': 10000,
#  'wind_speed': 10.45,
#  'wind_deg': 182,
#  'wind_gust': 18.24,
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': '온흐림',
#    'icon': '04d'}]}

# %% [markdown]
# - 도시 입력 -> 위도 경도 조회

# %%
def get_coordinates(city_name, api_key):
    """도시 이름으로 위도, 경도 조회"""
    url = f"http://api.openweathermap.org/geo/1.0/direct?q={city_name}&limit=1&appid={api_key}"
    response = requests.get(url)
    data = response.json()
    
    if not data:
        raise ValueError(f"도시 '{city_name}'에 대한 정보를 찾을 수 없습니다.")
    
    lat = data[0]['lat']
    lon = data[0]['lon']
    return lat, lon

# %%
lat, lon = get_coordinates("서울", open_weather_api_key)
print(lat, lon)
# Out:
# 37.5666791 126.9782914

# %%
api = f"""https://api.openweathermap.org/data/3.0/onecall/overview?lat={lat}&lon={lon}&appid={open_weather_api_key}"""

result = requests.get(api)
data = json.loads(result.text)

print(data)
# Out:
# {'lat': 37.5666791, 'lon': 126.9782914, 'tz': '+09:00', 'date': '2025-04-30', 'units': 'standard', 'weather_overview': 'Currently, the temperature is 298K with a "feels like" temperature of 297K. The pressure is at 1013 hPa, with a humidity of 25%. The dew point is at 277K, and the UV index is 4, indicating moderate risk of harm from unprotected sun exposure. The sky is clear with no clouds, and visibility is at 10000 meters. The wind speed is 5 meters per second coming from the south-southwest at 190 degrees. So, overall, it\'s a clear and sunny day with moderate temperatures and a light breeze. Perfect weather for outdoor activities!'}

# %%
print(data["weather_overview"])
# Out:
# Currently, the temperature is 298K with a "feels like" temperature of 297K. The pressure is at 1013 hPa, with a humidity of 25%. The dew point is at 277K, and the UV index is 4, indicating moderate risk of harm from unprotected sun exposure. The sky is clear with no clouds, and visibility is at 10000 meters. The wind speed is 5 meters per second coming from the south-southwest at 190 degrees. So, overall, it's a clear and sunny day with moderate temperatures and a light breeze. Perfect weather for outdoor activities!
